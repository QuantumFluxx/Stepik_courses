# %% [markdown]
# # 1. Рассмотрите игру, представленную в нормальной форме:
# ![](https://ucarecdn.com/a8803593-a5d5-411e-a9cd-a2b3a297c3b3/)
#
# Ответ: 2
#
# # 2. Рассмотрите игру, представленную в нормальной форме:
# ![](https://ucarecdn.com/d699d201-b0fc-49e4-a04d-b63eaf7e756f/)
#
# Ответ: 2
#
# # 3. В модели «дилемма заключённого» в зависимости от числа игроков игра является:
#
#
# * множественной
#
# * **парной**
#
# # 4. В модели «дилемма заключённого» по количеству информации игра является:
#
#
# * игрой с неполной информацией
#
# * **игрой с полной информацией**
#
# # 5. В модели «дилемма заключённого» по количеству стратегий игрока игра является:
#
#
# * бесконечной
#
# * **конечной**
#
# # 6. В модели «дилемма заключённого» по виду описания игры игра представлена:
#
#
# * в позиционной форме
#
# * **в нормальной форме**
#
# # 7. В модели «дилемма заключённого» по характеру выигрышей игра является игрой:
#
#
# * **с ненулевой суммой**
#
# * с нулевой суммой
#
# # 8. В модели «дилемма заключённого» по количеству ходов игра является:
#
#
# * **одноходовой**
#
# * многоходовой
#
# # 9. В модели «дилемма заключённого» по взаимоотношению участников игра является:
#
#
# * коалиционной
#
# * **бескоалиционной**
#
# * кооперативной
#
# # 10. В игре есть два игрока – автомобилист и страховая компания.
#
# У автомобилиста существуют следующие стратегии:
#
# А1 – управлять автомобилем предельно аккуратно и при заключении договора указывать настоящую стоимость автомобиля (200 тысяч рублей). В этом случае вероятность наступления страхового случая равна нулю.
#
# А2 – управлять автомобилем предельно аккуратно и при заключении договора со страховой компанией указать заниженную стоимость автомобиля (100 тысяч рублей).
#
# А3 – не следить за дорогой и указать завышенную стоимость автомобиля (300 тысяч рублей). Вероятность наступления страхового случая велика.
#
# Если страховая компания установит, что авария произошла по вине водителя (при проведении расследования в случае ДТП), то страховой выплаты не будет. Если страховая компания установит, что автомобилист указал завышенную или заниженную стоимость автомобиля, то автомобилист будет оштрафован на 20 % от реальной стоимости автомобиля. Страховой взнос составляет 10 % от указанной страховой суммы.
#
# У страховой компании существует четыре стратегии:
#
# B1 – не проводить оценку стоимости автомобиля и не заниматься расследованием в случае ДТП на предмет установления виновного.
#
# В2 – проводить расследование в случае наступления страхового случая, но не делать оценку стоимости автомобиля.
#
# В3 – проверять стоимость автомобиля, но не проводить расследование при ДТП.
#
# В4 – проводить расследование в случае ДТП и проверять, соответствует ли стоимость автомобиля реальной.
#
# Рассчитайте данные, которые будут включены в платёжную матрицу, если мы в таблице указываем значения для автомобилиста.
#
# **Если автомобилист выбирает стратегию A1, а страховая компания выбирает стратегию B1, то в платёжную матрицу вносим число _____**
#
# Ответ: -20000
#
# # 11. В игре есть два игрока – автомобилист и страховая компания.
#
# У автомобилиста существуют следующие стратегии:
#
# А1 – управлять автомобилем предельно аккуратно и при заключении договора указывать настоящую стоимость автомобиля (200 тысяч рублей). В этом случае вероятность наступления страхового случая равна нулю.
#
# А2 – управлять автомобилем предельно аккуратно и при заключении договора со страховой компанией указать заниженную стоимость автомобиля (100 тысяч рублей).
#
# А3 – не следить за дорогой и указать завышенную стоимость автомобиля (300 тысяч рублей). Вероятность наступления страхового случая велика.
#
# Если страховая компания установит, что авария произошла по вине водителя (при проведении расследования в случае ДТП), то страховой выплаты не будет. Если страховая компания установит, что автомобилист указал завышенную или заниженную стоимость автомобиля, то автомобилист будет оштрафован на 20 % от реальной стоимости автомобиля. Страховой взнос составляет 10 % от указанной страховой суммы.
#
# У страховой компании существует четыре стратегии:
#
# B1 – не проводить оценку стоимости автомобиля и не заниматься расследованием в случае ДТП на предмет установления виновного.
#
# В2 – проводить расследование в случае наступления страхового случая, но не делать оценку стоимости автомобиля.
#
# В3 – проверять стоимость автомобиля, но не проводить расследование при ДТП.
#
# В4 – проводить расследование в случае ДТП и проверять, соответствует ли стоимость автомобиля реальной.
#
# Рассчитайте данные, которые будут включены в платёжную матрицу, если мы в таблице указываем значения для автомобилиста.
#
# **Если автомобилист выбирает стратегию A3, а страховая компания выбирает стратегию B3, то в платёжную матрицу мы вносим число ______**
#
# Ответ: 130000
#
#
# # 12. В игре есть два игрока – автомобилист и страховая компания.
#
# У автомобилиста существуют следующие стратегии:
#
# А1 – управлять автомобилем предельно аккуратно и при заключении договора указывать настоящую стоимость автомобиля (200 тысяч рублей). В этом случае вероятность наступления страхового случая равна нулю.
#
# А2 – управлять автомобилем предельно аккуратно и при заключении договора со страховой компанией указать заниженную стоимость автомобиля (100 тысяч рублей).
#
# А3 – не следить за дорогой и указать завышенную стоимость автомобиля (300 тысяч рублей). Вероятность наступления страхового случая велика.
#
# Если страховая компания установит, что авария произошла по вине водителя (при проведении расследования в случае ДТП), то страховой выплаты не будет. Если страховая компания установит, что автомобилист указал завышенную или заниженную стоимость автомобиля, то автомобилист будет оштрафован на 20 % от реальной стоимости автомобиля. Страховой взнос составляет 10 % от указанной страховой суммы.
#
# У страховой компании существует четыре стратегии:
#
# B1 – не проводить оценку стоимости автомобиля и не заниматься расследованием в случае ДТП на предмет установления виновного.
#
# В2 – проводить расследование в случае наступления страхового случая, но не делать оценку стоимости автомобиля.
#
# В3 – проверять стоимость автомобиля, но не проводить расследование при ДТП.
#
# В4 – проводить расследование в случае ДТП и проверять, соответствует ли стоимость автомобиля реальной.
#
# Рассчитайте данные, которые будут включены в платёжную матрицу, если мы в таблице указываем значения для автомобилиста.
#
# **Если автомобилист выбирает стратегию A2, а страховая компания выбирает стратегию B4, то в платёжную матрицу вносим число______**
#
# Ответ: -50000
#
# # 13. В игре есть два игрока А и В, их выигрыши представлены в данной платёжной матрице:
# ![](https://ucarecdn.com/31c1e658-4d3e-4661-a9db-7063c839816e/)
# **Наилучшая стратегия для игрока A в соответствии с принципом максимина:**
#
#
# * А2
#
# * А3
#
# * А1
#
# * **А4**
#
# # 14. В игре есть два игрока А и В, их выигрыши представлены в данной платёжной матрице:
# ![](https://ucarecdn.com/61ec8000-6153-44ad-aaf2-9325bf970f57/)
# **Наилучшая стратегия для игрока B в соответствии с принципом минимакса:**
#
#
# * В4
#
# * В3
#
# * B1
#
# * **В2**
#
# # 15. В игре есть два игрока А и В, их выигрыши представлены в данной платёжной матрице:
# ![](https://ucarecdn.com/5d80e262-9ac3-4a96-a72e-d8687ee20c4c/)
# **Существует ли решения денной игры в чистых стратегиях? **
#
#
# * **Да**
#
# * Нет
#
# # 16. Вам дана платёжная матрица (значения указаны для игрока А, поэтому для игрока В будут те же значения с отрицательным знаком, поскольку это игра с нулевой суммой).
# ![](https://ucarecdn.com/1a601b80-ee14-4b26-b91a-0898067b12c1/)
# **Проанализируйте данную платёжную матрицу и в таблице отметьте соответствующие значения.**
#
#
# Стратегия
#
# А1
#
# **А2**
#
# А3
#
# **А4**
#
# **B1**
#
# B2
#
# B3
#
# **B4**
#
# # 17. На рынке действует две фирмы 1 и 2. Их стратегии и выигрыши представлены в платёжной матрице.
# ![](https://ucarecdn.com/7719c14e-cfde-46cf-9447-5c57defec589/)
# Первая цифра указана для фирмы 1, а вторая – для фирмы 2
#
# **Равновесию по Нэшу соответствует выбор следующих стратегий:**
#
#
# * **А; Г**
#
# * А; В
#
# * Б; Г
#
# * Б; В
#
# # 18. В отрасли действует две фирмы с одинаковыми обратными кривыми спроса P = 100 – 2Q, а предельные издержки постоянны и равны 10. Взаимодействие фирм описывается с помощью модели Курно.
# Чему будет равен объём производства каждой из фирм?
#
# Ответ: 15
#
# # 19. В отрасли действует две фирмы с одинаковыми обратными кривыми спроса P = 100 – 2Q, а предельные издержки постоянны и равны 10. Взаимодействие фирм описывается с помощью модели Курно.
# Чему будет равна цена товара?
#
# Ответ: 40
#
# # 20. В отрасли действует две фирмы с одинаковыми обратными кривыми спроса P = 100 – 2Q, а предельные издержки постоянны и равны 20. Взаимодействие фирм описывается с помощью модели Штакельберга.
# Чему будет равен объём производства фирмы-лидера?
#
# Ответ: 20
#
# # 21. В отрасли действует две фирмы с одинаковыми обратными кривыми спроса P = 100 – 2Q, а предельные издержки постоянны и равны 20. Взаимодействие фирм описывается с помощью модели Штакельберга.
# Чему будет равен объём производства фирмы-последователя?
#
# Ответ: 10
#
# # 22. В отрасли действует две фирмы с одинаковыми обратными кривыми спроса P = 100 – 2Q, а предельные издержки постоянны и равны 20. Взаимодействие фирм описывается с помощью модели Штакельберга.
# Чему будет равна цена товара?
#
# Ответ: 40
#
# # 23. Является ли игра «Международная торговля» статической игрой?
#
#
# * нет
#
# * **да**
#
# # 24. Изменятся ли таможенные пошлины, если одна из стран будет устанавливать свою таможенную пошлину первой?
#
#
# * **да**
#
# * нет
#
# # 25. Во сколько раз будет больше таможенная пошлина у лидера больше, чем у последователя?
#
#
# * в 4 раза
#
# * **в 2 раза**
#
# * в 8 раз
#
# # 26. Компания-аутсайдер принимает решение о том, стоит ли ей вступить на новый рынок.  Определите стратегии поведения для каждого участника.
# ![](https://ucarecdn.com/a1fd57f9-731c-4e8a-8ddd-5836bbbe92a2/)
#
#
# * **дружественная**
#
# * агрессивная
#
# # 27. Компания-аутсайдер принимает решение о том, стоит ли ей вступить на новый рынок.  Определите стратегии поведения для каждого участника.
# ![](https://ucarecdn.com/4c9c33c2-5d25-48e5-8010-0e78f55972b7/)
#
#
# * невступление на рынок
#
# * **вступление на рынок**
#
# # 28. В позиционной форме ниже представлена игра.
# ![](https://ucarecdn.com/f1e6cc2b-985e-4315-baf0-95f0d27ec0fe/)
# Представьте эту игру в нормальной форме.
#
# Сколько стратегий будет у игрока 1?
#
# Ответ: 2
#
# # 29. В позиционной форме ниже представлена игра.
# ![](https://ucarecdn.com/f1e6cc2b-985e-4315-baf0-95f0d27ec0fe/)
# Представьте эту игру в нормальной форме.
#
# Сколько стратегий будет у игрока 2?
#
# Ответ: 6
#
# # 30. Компания решает, вводить ли ей на рынок новый товар на рынок. На основе дерева решений представьте данную игру в нормальной форме.
# ![](https://ucarecdn.com/846f5bb5-09d9-40b5-86a5-28898206e2a9/)
# Стратегия компании А:
#
#
# * **не вводить новый товар**
#
# * вводить новый товар на рынок
#
#
# # 31. Компания решает, вводить ли ей на рынок новый товар на рынок. На основе дерева решений представьте данную игру в нормальной форме.
# ![](https://ucarecdn.com/3895262c-be4b-4f11-95a4-49a7010de488/)
# Стратегия компании Б:
#
#
# * отсутствие клонирования
#
# * **клонирование нового товара**
#
# # 32. Сколько собственных подыгр можно выделить в данной игре?
# ![](https://ucarecdn.com/70b28274-6615-4537-bb6b-acd827431441/)
#
#
# * **одну**
#
# * две
#
# * ни одной
#
# # 33. Рассмотрим ситуацию, когда две фирмы решают, стоит ли им осуществлять совместный проект. Если фирма откажется от совместного проекта, это соответствует варианту А, в этом случае первая и вторая фирма остаются со своей изначальной прибылью (по 3). Фирма 1 может вложит в проект небольшую (Б) или значительную сумму (В). После этого фирма 2 решает, вложить ли ей в совместный проект небольшую (Г) или большую сумму (Д), но при этом вторая фирма не знает, что выбрала первая фирма. Поскольку проект является достаточно рискованным, то фирмы могут и потерять деньги, особенно в том случае, если вложат в проект большую сумму. Первая цифра – для фирмы 1. Выберите оптимальную стратегию для каждого игрока.
#
# ![](https://ucarecdn.com/f43b2e05-15cf-497a-b7b1-f686ad8f1366/)
# Впишите соответствующую букву (заглавную, на русском языке):
#
# **Оптимальная стратегия для фирмы 1: B**
#
# **Оптимальная стратегия для фирмы 2: Д**
#
#
# # 34. Выберите черты игр, которые отличают игры с полной информацией от игр с неполной информацией:
#
#
# * **известна вероятность, с которой встречаются различные типы игроков**
#
# * число игроков больше двух
#
# * **игроки не знают, какие ходы были сделаны до них**
#
# * игры с неполной информацией могут быть представлены только в статической форме
#
# * **вначале Природа задает тип игрока**
#
# # 35. Ниже представлена игра в нормальной форме, которую мы рассматривали в предыдущем видео-уроке, но здесь дана вероятность, с которой может встретиться каждый из типов игроков (первая цифра – для игрока 1).
# ![](https://ucarecdn.com/8ac7ef53-1733-4f3a-b362-2737ba77a750/)
# Чему будет равна полезность первого игрока, предпочитающего IBM, если он выберет IBM?
#
# Ответ: 2.2
#
#
# # 36. Ниже представлена игра в нормальной форме, которую мы рассматривали в предыдущем видео-уроке, но здесь дана вероятность, с которой может встретиться каждый из типов игроков (первая цифра – для игрока 1).
# ![](https://ucarecdn.com/8ac7ef53-1733-4f3a-b362-2737ba77a750/)
# Чему будет равна полезность первого игрока, предпочитающего IBM, если он выберет Mac?
#
# Ответ: 0.8
#
#
# # 37. Если в игре про Гитлера и Чемберлена, которая была рассмотрена в предыдущем видео-уроке, изменится вероятность того, что  Гитлер является агрессивным или миролюбивым, повлияет ли это на решение, принимаемое Чемберленом (уступить Чехословакию)?
#
#
# * Нет
#
# * **Да**
#
#
# # 38. Если в игре, рассмотренной в предыдущем видео-уроке, Гитлер будет миролюбивым с вероятностью 0,4, а агрессивным с вероятностью 0,6, то чему будет равен выигрыш Чемберлена, если он уступит Чехословакию?
#
# Ответ: 1.8
#
# # 39. Если в данной игре Гитлер будет миролюбивым с вероятностью 0,4, а агрессивным с вероятностью 0,6, то чему будет равен выигрыш Чемберлена, если он не уступит Чехословакию?
#
# Ответ: 2
#
# # 40. Уступит ли в этом случае Чемберлен Чехословакию Гитлеру?
#
#
# * **Нет**
#
# * Да
#
#
# # 41. Рассмотрите следующую ситуацию. Преступник решает, похитить ли ему важные документы об авторском праве и потребовать выкуп за них. Для него возможные исходы могут быть проранжированы следующим образом: если он не похищает документы, исход для него будет равен 3, если он похитит документы и получит выкуп, исход равен 5, если он при этом вернёт документы и 4, если он их уничтожит, а если он похитит документы и не получит выкуп, то исход будет равен 2, если он уничтожит документы, и 1, если вернёт их. Потерпевшая компания должна решить, будет ли она платить выкуп. Для неё исходы ранжируются так: 5, если документы не похищают, 4, если документы вернут без уплаты выкупа, 3, если документы вернут после уплаты выкупа, 2, если документы уничтожат без уплаты выкупа, и 1, если документы уничтожат после уплаты выкупа.
#
# Постройте на отдельном листочке дерево решений и определите, какие стратегии будут выбраны преступником и потерпевшей компанией.
# Оптимальная стратегия для преступника:
#
#
# * **преступник похитит документы**
#
# * преступник не будет похищать документы
#
# # 42. Рассмотрите следующую ситуацию. Преступник решает, похитить ли ему важные документы об авторском праве и потребовать выкуп за них. Для него возможные исходы могут быть проранжированы следующим образом: если он не похищает документы, исход для него будет равен 3, если он похитит документы и получит выкуп, исход равен 5, если он при этом вернёт документы и 4, если он их уничтожит, а если он похитит документы и не получит выкуп, то исход будет равен 2, если он уничтожит документы, и 1, если вернёт их. Потерпевшая компания должна решить, будет ли она платить выкуп. Для неё исходы ранжируются так: 5, если документы не похищают, 4, если документы вернут без уплаты выкупа, 3, если документы вернут после уплаты выкупа, 2, если документы уничтожат без уплаты выкупа, и 1, если документы уничтожат после уплаты выкупа.
#
# Постройте на отдельном листочке дерево решений и определите, какие стратегии будут выбраны преступником и потерпевшей компанией.
# Оптимальная стратегия для компании:
#
#
# * **заплатить выкуп**
#
# * не платить выкуп
#
# # 43. Рассмотрите следующую ситуацию. Преступник решает, похитить ли ему важные документы об авторском праве и потребовать выкуп за них. Для него возможные исходы могут быть проранжированы следующим образом: если он не похищает документы, исход для него будет равен 3, если он похитит документы и получит выкуп, исход равен 5, если он при этом вернёт документы и 4, если он их уничтожит, а если он похитит документы и не получит выкуп, то исход будет равен 2, если он уничтожит документы, и 1, если вернёт их. Потерпевшая компания должна решить, будет ли она платить выкуп. Для неё исходы ранжируются так: 5, если документы не похищают, 4, если документы вернут без уплаты выкупа, 3, если документы вернут после уплаты выкупа, 2, если документы уничтожат без уплаты выкупа, и 1, если документы уничтожат после уплаты выкупа.
#
# Постройте на отдельном листочке дерево решений и определите, какие стратегии будут выбраны преступником и потерпевшей компанией.
# Если преступник похитит документы, то:
#
#
# * **он вернёт их после получения выкупа**
#
# * он не станет их возвращать после получения выкупа
#
# # 44. К предыдущей задаче добавляем условие, что похититель может быть двух типов: с вероятностью 70 % мирный (его распределение приоритетов описано в предыдущей задаче), а с вероятностью 30 % агрессивный, и тогда для него исходы ранжируются так: если он не станет похищать документы, исход для него будет равен 2, если он похитит документы и получит выкуп, исход равен 4, если он при этом вернёт документы и 5, если он их уничтожит, а если он похитит документы и не получит выкуп, то исход будет равен 3, если он уничтожит документы, и 1, если вернёт документы. На отдельном листочке составьте дерево решений.
#
# Рассчитайте выигрыш компании в том случае, если компания не знает, к какому типу относится похититель и решает заплатить выкуп:
#
# Ответ: 2.4
#
#
# # 45. К предыдущей задаче добавляем условие, что похититель может быть двух типов: с вероятностью 70 % мирный (его распределение приоритетов описано в предыдущей задаче), а с вероятностью 30 % агрессивный, и тогда для него исходы ранжируются так: если он не станет похищать документы, исход для него будет равен 2, если он похитит документы и получит выкуп, исход равен 4, если он при этом вернёт документы и 5, если он их уничтожит, а если он похитит документы и не получит выкуп, то исход будет равен 3, если он уничтожит документы, и 1, если вернёт документы. На отдельном листочке составьте дерево решений.
#
# Рассчитайте выигрыш компании в том случае, если компания не знает, к какому типу относится похититель и решает не платить выкуп:
#
# Ответ: 2
#
# # 46. Будет ли компания платить выкуп в данном случае?
#
#
# * **да**
#
# * нет
#
#
# # 47. В чём смысл стратегии «зуб за зуб»:
#
#
# * нарушить соглашение независимо от поведения контрагента
#
# * продолжать сотрудничать с противником независимо от его поведения, чтобы создать себе репутацию надёжного партнёра
#
# * не вступать в сотрудничество с другой компанией
#
# * **продолжать сотрудничество, если противник шёл на сотрудничество в предыдущем раунде, и нарушать соглашение, если противник его нарушил в предыдущем раунде**
#
#
# # 48. В случае конечной игры фирмам выгодно придерживаться соглашения о договорённости?
#
#
# * **Нет**
#
# * Да
#
# # 49. В случае бесконечной игры фирмам выгодно придерживаться соглашения о договорённости?
#
#
# * Нет
#
# * **Да**
#
#
# # 50. Возможные выигрыши трёх участников, которые хотят объединиться в коалицию, составляют:
#
# а) х1 = 3, х2 = 6, х4 = 3;
#
# б) x1 = 2, x2 = 6; x3 = 4;
#
# в) x1 = 1; x2 = 3; x3 = 8.
#
# В случае справедливого компромисса каждый их участников получит:
#
# первый участник ____
#
# Ответ: 2
#
# # 51. Возможные выигрыши трёх участников, которые хотят объединиться в коалицию, составляют:
#
# а) х1 = 3, х2 = 6, х4 = 3;
#
# б) x1 = 2, x2 = 6; x3 = 4;
#
# в) x1 = 1; x2 = 3; x3 = 8.
#
# В случае справедливого компромисса каждый их участников получит:
#
# второй участник _____
#
# Ответ: 5
#
#
# # 52. Возможные выигрыши трёх участников, которые хотят объединиться в коалицию, составляют:
#
# а) х1 = 3, х2 = 6, х4 = 3;
#
# б) x1 = 2, x2 = 6; x3 = 4;
#
# в) x1 = 1; x2 = 3; x3 = 8.
#
# В случае справедливого компромисса каждый их участников получит:
#
# третий участник ____
#
# Ответ: 5
#
#
# # 53. Как называется аукцион, при котором товар получает тот, кто оценивает данный товар выше всех:
#
#
# * **эффективный аукцион**
#
# * оптимальный аукцион
#
# * голландский аукцион
#
# # 54. При продаже картины Ван Гога на аукционе речь идёт:
#
#
# * об аукционе с общей оценкой товара
#
# * о японском аукционе
#
# * **об аукционе с частной оценкой товара**
#
# # 55. Кто выигрывает аукцион Викри?
#
#
#
# * **участник, предложивший наибольшую цену**
#
# * участник, назвавший цену, которая оказывается ближе всех к общей оценке данного блага
#
# * участник, предложивший вторую цену после максимальной
#
# # 56. Какую цену платит победитель аукциона Викри:
#
#
# * среднюю цену между первой и второй поданными ценами
#
# * **цену, которую предложил участник, занявший второе место на торгах**
#
# * цену, которую он предложил
#
# # 57. В аукционе первой цены выигрывает:
#
#
# * участник, назвавший цену, которая оказывается ближе всех к общей оценке данного блага
#
# * **участник, предложивший наибольшую цену**
#
# * участник, предложивший вторую цену после максимальной
#
# # 58. В голландском аукционе участник делает ставку аналогично тому, как он делал бы при участии в:
#
#
# * аукционе Викри
#
# * **аукционе первой цены**
#
# * английском аукционе
#
#
#
# -------------------
# # Литература по курсу
#
# ## Основная литература:
# 1. Бусыгин В.П., Желободько Е.В., Цыплаков А.А. Микроэкономика: третий уровень: в 2 томах, т.2. – Новосибирск, изд-во СО РАН, 2008 // http://math.nsc.ru/~mathecon/Marakulin/For%20Students/Micro3_Book
#
# 2. Тарасевич Л.С., Гребенников П.И., Леусский А.И. Макроэкономика. 7-е изд. – М.: Издательство Юрайт, 2014.
#
#
#
# ## Дополнительная литература:
# 1. Лабскер Л.Г., Ященко Н.А. Теория игр в экономике (практикум с решениями задач): учебное пособие. – М.: КНОРУС, 2014.
#
# 2. Акерлоф Дж. Рынок «лимонов»: неопределённость качества и рыночный механизм, THESIS, 1994, вып.5, сс. 91-104 // https://igiti.hse.ru/data/413/313/1234/5_1_4Akerl.pdf
#
# 3. Захаров А.В. Теория игр в общественных науках : учебник для вузов / науч. ред. А.В. Савватеев. - М. : Издательский дом Высшей школы экономики, 2015. - 303 с. - URL: http://biblioclub.ru/index.php?page=book&id=439990
#
# 4. Шелехова Л.В. Теория игр в экономике : учебное пособие. - М. ; Берлин : Директ-Медиа, 2015. - 119 с. - URL: http://biblioclub.ru/index.php?page=book&id=274522
