# %% [markdown]
# # 1. Тип данных, который может иметь только один экземпляр называется
#
#
# * декоратор
#
# * наблюдатель
#
# * мультитон
#
# * адаптер
#
# * прототип
#
# * **синглтон**
#
#
# # 2. Можно ли самостоятельно создать другой NoneType объект, кроме None?
#
#
# * **нет**
#
# * да
#
# # 3. Предпочтительным способом сравнения на None является
#
#
# * оператор ==
#
# * **оператор is**
#
#
# # 4. Что будет выведено на экран в результате выполнения следующей программы?
#
# print(None == None)
#
#
# * False
#
# * **True**
#
# # 5. Что будет выведено на экран в результате выполнения следующей программы?
#
# print(None == 0)
#
#
# * **False**
#
# * True
#
# # 6. Что будет выведено на экран в результате выполнения следующей программы?
#
# print(None == False)
#
# * **False**
#
# * True
#
# # 7. Что будет выведено на экран в результате выполнения следующей программы?
#
# empty = ''
#
# print(None == empty)
#
#
#
# * **False**
#
# * True
#
#
# # 8. Верно ли, что функции не содержащие явной инструкции return, на самом деле возвращают значение None?
#
# Примечание. Считайте, что речь идет о функциях, не относящихся к анонимным (лямбда-функциям) и функциям-генераторам.
#
#
# * не всегда
#
# * нет
#
# * **да**
